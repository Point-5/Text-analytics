# %%
import os # operating system operations like check files existance
import datetime # time and date operations
import gc # garbage collector
import pandas as pd # data frames wrangling
import numpy as np # math functions
from IPython.core.interactiveshell import InteractiveShell
import matplotlib.pyplot as plt


InteractiveShell.ast_node_interactivity = "all"  # multiple output per jupyter notebook code block

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf
from sklearn.model_selection import train_test_split

# %%
crypto = pd.read_csv('twtcrypto.csv')

# %%
crypto.head()
# Out:
#    Unnamed: 0   datetime  num  nega  posi  Sentiment    close  close_nextday  \
# 0           0  2020/1/21   20     8    12   0.600000  8745.89        8680.88
# 1           1  2020/1/22   28    17    11   0.392857  8680.88        8406.52
# 2           2  2020/1/23   55    24    31   0.563636  8406.52        8445.43
# 3           3  2020/1/24   44    23    21   0.477273  8445.43        8367.85
# 4           4  2020/1/25   51    35    16   0.313725  8367.85        8596.83
#
#    daily return          vol      mktcap
# 0     -0.007433  24097418512  158.947997
# 1     -0.031605  22600204051  157.783273
# 2      0.004629  25770680779  152.813330
# 3     -0.009186  24397913026  153.536830
# 4      0.027364  19647331549  152.143263

# %%
def runplt(x, y,yl):
    plt.figure()
    plt.title("predicted-actual value comparison")
    plt.xlabel("date point")
    if yl == 'Bitcoin Price':
            plt.ylabel("Bitcoin Price")
    elif yl == 'Bitcoin Price Next Day':
            plt.ylabel("Bitcoin Price Next Day")
    elif yl == 'Bitcoin Trading Volume':
            plt.ylabel("Bitcoin Traindg Volume")
    elif yl == 'Bitcoin Daily Return':
            plt.ylabel("Bitcoin Daily Return")
    plt.plot(range(len(x)),x,'b',label="predict")
    plt.plot(range(len(y)),y,'r',label="test")
    plt.legend(loc="upper right")
    plt.grid(True)
    return plt

# %%
X=pd.DataFrame(crypto,columns=['num'])
y=crypto.close_nextday
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)
X_train=sm.add_constant(X_train)
model=sm.OLS(y_train,X_train).fit()
print(model.summary())
pred_value=model.params[0]+model.params[1]*X_test.num

# ---------- plot2
plt=runplt(pred_value,y_test, 'Bitcoin Price Next Day')
# plt.plot(pred_value,y_test)
plt.show()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          close_nextday   R-squared:                       0.507
# Model:                            OLS   Adj. R-squared:                  0.495
# Method:                 Least Squares   F-statistic:                     43.16
# Date:                Fri, 10 Apr 2020   Prob (F-statistic):           6.01e-08
# Time:                        20:15:43   Log-Likelihood:                -371.34
# No. Observations:                  44   AIC:                             746.7
# Df Residuals:                      42   BIC:                             750.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       9597.5886    241.150     39.799      0.000    9110.929    1.01e+04
# num           -2.3056      0.351     -6.570      0.000      -3.014      -1.597
# ==============================================================================
# Omnibus:                        5.235   Durbin-Watson:                   1.976
# Prob(Omnibus):                  0.073   Jarque-Bera (JB):                4.548
# Skew:                          -0.786   Prob(JB):                        0.103
# Kurtosis:                       3.101   Cond. No.                         959.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
X=pd.DataFrame(crypto,columns=['num','nega','posi'])
y=crypto['daily return']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
X_train=sm.add_constant(X_train)
model=sm.OLS(y_train,X_train).fit()
print(model.summary())
pred_value=model.params[0]+model.params[1]*X_test.num+model.params[2]*X_test.nega+model.params[3]*X_test.posi
# ---------- plot2
plt=runplt(pred_value,y_test,'Bitcoin Daily Return')
# plt.plot(pred_value,y_test)
plt.show()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           daily return   R-squared:                       0.119
# Model:                            OLS   Adj. R-squared:                  0.056
# Method:                 Least Squares   F-statistic:                     1.897
# Date:                Fri, 10 Apr 2020   Prob (F-statistic):              0.169
# Time:                        20:15:43   Log-Likelihood:                 35.332
# No. Observations:                  31   AIC:                            -64.66
# Df Residuals:                      28   BIC:                            -60.36
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0010      0.021      0.047      0.963      -0.042       0.044
# num        -6.525e-05   3.76e-05     -1.733      0.094      -0.000    1.19e-05
# nega           0.0005      0.000      1.925      0.064   -3.49e-05       0.001
# posi          -0.0006      0.000     -1.941      0.062      -0.001    3.37e-05
# ==============================================================================
# Omnibus:                       28.467   Durbin-Watson:                   2.080
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              112.286
# Skew:                          -1.577   Prob(JB):                     4.14e-25
# Kurtosis:                      11.774   Cond. No.                     7.64e+15
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 3.55e-25. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
X=pd.DataFrame(crypto,columns=['num'])
y=crypto.vol
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)
X_train=sm.add_constant(X_train)
model=sm.OLS(y_train,X_train).fit()
print(model.summary())
pred_value=model.params[0]+model.params[1]*X_test.num

# ---------- plot2
plt=runplt(pred_value,y_test,'Bitcoin Trading Volume')
# plt.plot(pred_value,y_test)
plt.show()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    vol   R-squared:                       0.391
# Model:                            OLS   Adj. R-squared:                  0.377
# Method:                 Least Squares   F-statistic:                     26.99
# Date:                Fri, 10 Apr 2020   Prob (F-statistic):           5.64e-06
# Time:                        20:15:43   Log-Likelihood:                -1061.6
# No. Observations:                  44   AIC:                             2127.
# Df Residuals:                      42   BIC:                             2131.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       3.342e+10   1.57e+09     21.334      0.000    3.03e+10    3.66e+10
# num         1.184e+07   2.28e+06      5.195      0.000    7.24e+06    1.64e+07
# ==============================================================================
# Omnibus:                       11.459   Durbin-Watson:                   1.855
# Prob(Omnibus):                  0.003   Jarque-Bera (JB):               11.596
# Skew:                           1.005   Prob(JB):                      0.00303
# Kurtosis:                       4.512   Cond. No.                         959.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
